# %%
import pandas as pd
import re
from utils import *
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import nltk 
from bs4 import BeautifulSoup
from emot.emo_unicode import UNICODE_EMOJI 
from emot.emo_unicode import EMOTICONS_EMO 
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
from nltk import tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import subjectivity
from nltk.sentiment import SentimentAnalyzer
from nltk.sentiment.util import *
from sklearn.feature_extraction.text import TfidfVectorizer
from tqdm.notebook import tqdm 
import string 
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore")

# %%
# Read csv
df = pd.read_csv("data_w_gender_franyang_oct_18.csv")

# %%
df
# Out:
#                      Name                                             Review  \
# 0          Norman Johnson  Tinder would be so much better if we could spe...
# 1              David Hume  Still doesn't correctly notify matches or mess...
# 2        Arthur Magamedov                                           Love it!
# 3         Lukas Rukštelis                                          Good app.
# 4               Joe burns  Just tested after originally noticing a flux ;...
# ...                   ...                                                ...
# 391058  Shraddha Nigdikar  I don't see why this one is any different than...
# 391059       Helen Rogers  AWFUL!  *PROFILE FRAUD ALERT*  NO Facebook Fri...
# 391060    Lindsay Maguire  I first gave this app 1 star!, but they addres...
# 391061        Jennifer A.  Why on earth would you only allow people with ...
# 391062       Angela Beard  Not ready to go live. You can't even get past ...
#
#         Rating  #ThumbsUp         Date&Time     App Gender
# 0            3          0  18-02-2022 01:16  Tinder    Men
# 1            1          0  18-02-2022 01:11  Tinder    Men
# 2            5          0  18-02-2022 01:06  Tinder    Men
# 3            5          0  18-02-2022 00:57  Tinder    Men
# 4            1          0  18-02-2022 00:37  Tinder    Men
# ...        ...        ...               ...     ...    ...
# 391058       2          0  13-07-2017 22:52   Hinge  Women
# 391059       2          0  13-07-2017 04:12   Hinge  Women
# 391060       3         11  12-07-2017 15:44   Hinge  Women
# 391061       1          0  12-07-2017 02:33   Hinge  Women
# 391062       1          0  12-07-2017 02:05   Hinge  Women
#
# [391063 rows x 7 columns]

# %% [markdown]
# ### Preprocessing

# %%
def clean_text_lemma(my_text):
   # lemmatizing 
    lemmatizer = WordNetLemmatizer()
    my_text = lemmatizer.lemmatize(my_text)
    
    # change emojis into words 
    for emot in UNICODE_EMOJI:
        my_text = my_text.replace(emot, "_".join(UNICODE_EMOJI[emot].replace(",","").replace(":","").split()))

    return my_text

# %%
df['review_lemma'] = df['Review'].apply(lambda x: clean_text_lemma(x))

# %%
df
# Out:
#                      Name                                             Review  \
# 0          Norman Johnson  Tinder would be so much better if we could spe...
# 1              David Hume  Still doesn't correctly notify matches or mess...
# 2        Arthur Magamedov                                           Love it!
# 3         Lukas Rukštelis                                          Good app.
# 4               Joe burns  Just tested after originally noticing a flux ;...
# ...                   ...                                                ...
# 391058  Shraddha Nigdikar  I don't see why this one is any different than...
# 391059       Helen Rogers  AWFUL!  *PROFILE FRAUD ALERT*  NO Facebook Fri...
# 391060    Lindsay Maguire  I first gave this app 1 star!, but they addres...
# 391061        Jennifer A.  Why on earth would you only allow people with ...
# 391062       Angela Beard  Not ready to go live. You can't even get past ...
#
#         Rating  #ThumbsUp         Date&Time     App Gender  \
# 0            3          0  18-02-2022 01:16  Tinder    Men
# 1            1          0  18-02-2022 01:11  Tinder    Men
# 2            5          0  18-02-2022 01:06  Tinder    Men
# 3            5          0  18-02-2022 00:57  Tinder    Men
# 4            1          0  18-02-2022 00:37  Tinder    Men
# ...        ...        ...               ...     ...    ...
# 391058       2          0  13-07-2017 22:52   Hinge  Women
# 391059       2          0  13-07-2017 04:12   Hinge  Women
# 391060       3         11  12-07-2017 15:44   Hinge  Women
# 391061       1          0  12-07-2017 02:33   Hinge  Women
# 391062       1          0  12-07-2017 02:05   Hinge  Women
#
#                                              review_lemma  \
# 0       Tinder would be so much better if we could spe...
# 1       Still doesn't correctly notify matches or mess...
# 2                                                Love it!
# 3                                               Good app.
# 4       Just tested after originally noticing a flux ;...
# ...                                                   ...
# 391058  I don't see why this one is any different than...
# 391059  AWFUL!  *PROFILE FRAUD ALERT*  NO Facebook Fri...
# 391060  I first gave this app 1 star!, but they addres...
# 391061  Why on earth would you only allow people with ...
# 391062  Not ready to go live. You can't even get past ...
#
#                                          review_tokenized
# 0       [Tinder would be so much better if we could sp...
# 1       [Still doesn't correctly notify matches or mes...
# 2                                              [Love it!]
# 3                                             [Good app.]
# 4       [Just tested after originally noticing a flux ...
# ...                                                   ...
# 391058  [I don't see why this one is any different tha...
# 391059  [AWFUL!, *PROFILE FRAUD ALERT*  NO Facebook Fr...
# 391060  [I first gave this app 1 star!, but they addre...
# 391061  [Why on earth would you only allow people with...
# 391062  [Not ready to go live., You can't even get pas...
#
# [391063 rows x 9 columns]

# %% [markdown]
# ### Sentiment analysis

# %%
sia = SentimentIntensityAnalyzer()

# %%
df['sent_score'] = df['review_lemma'].map(lambda x: sia.polarity_scores(x))

# %%
df
# Out:
#                      Name                                             Review  \
# 0          Norman Johnson  Tinder would be so much better if we could spe...
# 1              David Hume  Still doesn't correctly notify matches or mess...
# 2        Arthur Magamedov                                           Love it!
# 3         Lukas Rukštelis                                          Good app.
# 4               Joe burns  Just tested after originally noticing a flux ;...
# ...                   ...                                                ...
# 391058  Shraddha Nigdikar  I don't see why this one is any different than...
# 391059       Helen Rogers  AWFUL!  *PROFILE FRAUD ALERT*  NO Facebook Fri...
# 391060    Lindsay Maguire  I first gave this app 1 star!, but they addres...
# 391061        Jennifer A.  Why on earth would you only allow people with ...
# 391062       Angela Beard  Not ready to go live. You can't even get past ...
#
#         Rating  #ThumbsUp         Date&Time     App Gender  \
# 0            3          0  18-02-2022 01:16  Tinder    Men
# 1            1          0  18-02-2022 01:11  Tinder    Men
# 2            5          0  18-02-2022 01:06  Tinder    Men
# 3            5          0  18-02-2022 00:57  Tinder    Men
# 4            1          0  18-02-2022 00:37  Tinder    Men
# ...        ...        ...               ...     ...    ...
# 391058       2          0  13-07-2017 22:52   Hinge  Women
# 391059       2          0  13-07-2017 04:12   Hinge  Women
# 391060       3         11  12-07-2017 15:44   Hinge  Women
# 391061       1          0  12-07-2017 02:33   Hinge  Women
# 391062       1          0  12-07-2017 02:05   Hinge  Women
#
#                                              review_lemma  \
# 0       Tinder would be so much better if we could spe...
# 1       Still doesn't correctly notify matches or mess...
# 2                                                Love it!
# 3                                               Good app.
# 4       Just tested after originally noticing a flux ;...
# ...                                                   ...
# 391058  I don't see why this one is any different than...
# 391059  AWFUL!  *PROFILE FRAUD ALERT*  NO Facebook Fri...
# 391060  I first gave this app 1 star!, but they addres...
# 391061  Why on earth would you only allow people with ...
# 391062  Not ready to go live. You can't even get past ...
#
#                                          review_tokenized  \
# 0       [Tinder would be so much better if we could sp...
# 1       [Still doesn't correctly notify matches or mes...
# 2                                              [Love it!]
# 3                                             [Good app.]
# 4       [Just tested after originally noticing a flux ...
# ...                                                   ...
# 391058  [I don't see why this one is any different tha...
# 391059  [AWFUL!, *PROFILE FRAUD ALERT*  NO Facebook Fr...
# 391060  [I first gave this app 1 star!, but they addre...
# 391061  [Why on earth would you only allow people with...
# 391062  [Not ready to go live., You can't even get pas...
#
#                                                sent_score
# 0       {'neg': 0.0, 'neu': 0.874, 'pos': 0.126, 'comp...
# 1       {'neg': 0.147, 'neu': 0.776, 'pos': 0.077, 'co...
# 2       {'neg': 0.0, 'neu': 0.182, 'pos': 0.818, 'comp...
# 3       {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'comp...
# 4       {'neg': 0.0, 'neu': 0.95, 'pos': 0.05, 'compou...
# ...                                                   ...
# 391058  {'neg': 0.0, 'neu': 0.903, 'pos': 0.097, 'comp...
# 391059  {'neg': 0.214, 'neu': 0.544, 'pos': 0.242, 'co...
# 391060  {'neg': 0.038, 'neu': 0.876, 'pos': 0.086, 'co...
# 391061  {'neg': 0.0, 'neu': 0.745, 'pos': 0.255, 'comp...
# 391062  {'neg': 0.131, 'neu': 0.869, 'pos': 0.0, 'comp...
#
# [391063 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['Name', 'Review', 'Rating', '#ThumbsUp', 'Date&Time', 'App', 'Gender',
#        'review_lemma', 'review_tokenized', 'sent_score'],
#       dtype='object')

# %%
df2 = df[['Name', 'Review', 'Rating', '#ThumbsUp', 'Date&Time', 'App', 'Gender','review_lemma']]

# %%
sentiments = pd.json_normalize(df['sent_score'])

# %%
sentiments
# Out:
#           neg    neu    pos  compound
# 0       0.000  0.874  0.126    0.4902
# 1       0.147  0.776  0.077   -0.7380
# 2       0.000  0.182  0.818    0.6696
# 3       0.000  0.256  0.744    0.4404
# 4       0.000  0.950  0.050    0.0258
# ...       ...    ...    ...       ...
# 391058  0.000  0.903  0.097    0.4404
# 391059  0.214  0.544  0.242   -0.3517
# 391060  0.038  0.876  0.086    0.5407
# 391061  0.000  0.745  0.255    0.4767
# 391062  0.131  0.869  0.000   -0.2755
#
# [391063 rows x 4 columns]

# %%
# Merge on index
df3 = df2.join(sentiments, how='outer')
df3
# Out:
#                      Name                                             Review  \
# 0          Norman Johnson  Tinder would be so much better if we could spe...
# 1              David Hume  Still doesn't correctly notify matches or mess...
# 2        Arthur Magamedov                                           Love it!
# 3         Lukas Rukštelis                                          Good app.
# 4               Joe burns  Just tested after originally noticing a flux ;...
# ...                   ...                                                ...
# 391058  Shraddha Nigdikar  I don't see why this one is any different than...
# 391059       Helen Rogers  AWFUL!  *PROFILE FRAUD ALERT*  NO Facebook Fri...
# 391060    Lindsay Maguire  I first gave this app 1 star!, but they addres...
# 391061        Jennifer A.  Why on earth would you only allow people with ...
# 391062       Angela Beard  Not ready to go live. You can't even get past ...
#
#         Rating  #ThumbsUp         Date&Time     App Gender  \
# 0            3          0  18-02-2022 01:16  Tinder    Men
# 1            1          0  18-02-2022 01:11  Tinder    Men
# 2            5          0  18-02-2022 01:06  Tinder    Men
# 3            5          0  18-02-2022 00:57  Tinder    Men
# 4            1          0  18-02-2022 00:37  Tinder    Men
# ...        ...        ...               ...     ...    ...
# 391058       2          0  13-07-2017 22:52   Hinge  Women
# 391059       2          0  13-07-2017 04:12   Hinge  Women
# 391060       3         11  12-07-2017 15:44   Hinge  Women
# 391061       1          0  12-07-2017 02:33   Hinge  Women
# 391062       1          0  12-07-2017 02:05   Hinge  Women
#
#                                              review_lemma    neg    neu  \
# 0       Tinder would be so much better if we could spe...  0.000  0.874
# 1       Still doesn't correctly notify matches or mess...  0.147  0.776
# 2                                                Love it!  0.000  0.182
# 3                                               Good app.  0.000  0.256
# 4       Just tested after originally noticing a flux ;...  0.000  0.950
# ...                                                   ...    ...    ...
# 391058  I don't see why this one is any different than...  0.000  0.903
# 391059  AWFUL!  *PROFILE FRAUD ALERT*  NO Facebook Fri...  0.214  0.544
# 391060  I first gave this app 1 star!, but they addres...  0.038  0.876
# 391061  Why on earth would you only allow people with ...  0.000  0.745
# 391062  Not ready to go live. You can't even get past ...  0.131  0.869
#
#           pos  compound
# 0       0.126    0.4902
# 1       0.077   -0.7380
# 2       0.818    0.6696
# 3       0.744    0.4404
# 4       0.050    0.0258
# ...       ...       ...
# 391058  0.097    0.4404
# 391059  0.242   -0.3517
# 391060  0.086    0.5407
# 391061  0.255    0.4767
# 391062  0.000   -0.2755
#
# [391063 rows x 12 columns]

# %%
# Determing sentiments from compound score
df3['Sentiment'] = ['Positive' if x>=0.05 else 'Neutral' if -0.05<x<0.05 else 'Negative' for x in df3['compound']]
df3
# Out:
#                      Name                                             Review  \
# 0          Norman Johnson  Tinder would be so much better if we could spe...
# 1              David Hume  Still doesn't correctly notify matches or mess...
# 2        Arthur Magamedov                                           Love it!
# 3         Lukas Rukštelis                                          Good app.
# 4               Joe burns  Just tested after originally noticing a flux ;...
# ...                   ...                                                ...
# 391058  Shraddha Nigdikar  I don't see why this one is any different than...
# 391059       Helen Rogers  AWFUL!  *PROFILE FRAUD ALERT*  NO Facebook Fri...
# 391060    Lindsay Maguire  I first gave this app 1 star!, but they addres...
# 391061        Jennifer A.  Why on earth would you only allow people with ...
# 391062       Angela Beard  Not ready to go live. You can't even get past ...
#
#         Rating  #ThumbsUp         Date&Time     App Gender  \
# 0            3          0  18-02-2022 01:16  Tinder    Men
# 1            1          0  18-02-2022 01:11  Tinder    Men
# 2            5          0  18-02-2022 01:06  Tinder    Men
# 3            5          0  18-02-2022 00:57  Tinder    Men
# 4            1          0  18-02-2022 00:37  Tinder    Men
# ...        ...        ...               ...     ...    ...
# 391058       2          0  13-07-2017 22:52   Hinge  Women
# 391059       2          0  13-07-2017 04:12   Hinge  Women
# 391060       3         11  12-07-2017 15:44   Hinge  Women
# 391061       1          0  12-07-2017 02:33   Hinge  Women
# 391062       1          0  12-07-2017 02:05   Hinge  Women
#
#                                              review_lemma    neg    neu  \
# 0       Tinder would be so much better if we could spe...  0.000  0.874
# 1       Still doesn't correctly notify matches or mess...  0.147  0.776
# 2                                                Love it!  0.000  0.182
# 3                                               Good app.  0.000  0.256
# 4       Just tested after originally noticing a flux ;...  0.000  0.950
# ...                                                   ...    ...    ...
# 391058  I don't see why this one is any different than...  0.000  0.903
# 391059  AWFUL!  *PROFILE FRAUD ALERT*  NO Facebook Fri...  0.214  0.544
# 391060  I first gave this app 1 star!, but they addres...  0.038  0.876
# 391061  Why on earth would you only allow people with ...  0.000  0.745
# 391062  Not ready to go live. You can't even get past ...  0.131  0.869
#
#           pos  compound Sentiment
# 0       0.126    0.4902  Positive
# 1       0.077   -0.7380  Negative
# 2       0.818    0.6696  Positive
# 3       0.744    0.4404  Positive
# 4       0.050    0.0258   Neutral
# ...       ...       ...       ...
# 391058  0.097    0.4404  Positive
# 391059  0.242   -0.3517  Negative
# 391060  0.086    0.5407  Positive
# 391061  0.255    0.4767  Positive
# 391062  0.000   -0.2755  Negative
#
# [391063 rows x 13 columns]

# %%
df3.iloc[500]
# Out:
# Name                                                Tyrell Nathan
# Review          Paid for the tinder plus several times. Would ...
# Rating                                                          1
# #ThumbsUp                                                       0
# Date&Time                                        10-02-2022 22:30
# App                                                        Tinder
# Gender                                                        Men
# review_lemma    Paid for the tinder plus several times. Would ...
# neg                                                           0.1
# neu                                                         0.829
# pos                                                         0.071
# compound                                                  -0.4753
# Sentiment                                                Negative
# Name: 500, dtype: object

# %%
df3['Sentiment'].value_counts()
# Out:
# Positive    201897
# Negative    113488
# Neutral      75678
# Name: Sentiment, dtype: int64

# %%
df3.to_csv('df_w_sentiments_nov16_franyang.csv',index=False)
