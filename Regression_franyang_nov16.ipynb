# %%
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('df_w_sentiments_nov17_franyang.csv')

# %%
df
# Out:
#                      Name                                             Review  \
# 0          Norman Johnson  Tinder would be so much better if we could spe...
# 1              David Hume  Still doesn't correctly notify matches or mess...
# 2        Arthur Magamedov                                           Love it!
# 3         Lukas Rukštelis                                          Good app.
# 4               Joe burns  Just tested after originally noticing a flux ;...
# ...                   ...                                                ...
# 391058  Shraddha Nigdikar  I don't see why this one is any different than...
# 391059       Helen Rogers  AWFUL!  *PROFILE FRAUD ALERT*  NO Facebook Fri...
# 391060    Lindsay Maguire  I first gave this app 1 star!, but they addres...
# 391061        Jennifer A.  Why on earth would you only allow people with ...
# 391062       Angela Beard  Not ready to go live. You can't even get past ...
#
# ...

# %%
# Setting the benchmark app to Tinder
df['App'] = pd.Categorical(df['App'], ["Tinder", "Bumble", "Hinge"])
# Setting the default gender to Women
df['Gender'] = pd.Categorical(df['Gender'], ["Women", "Men"])
df = df.sort_values(['App','Gender'])

# %%
# OLS
lm = smf.ols(formula = 'Rating~ compound + App + Gender + year', data = df).fit()
print (lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Rating   R-squared:                       0.331
# Model:                            OLS   Adj. R-squared:                  0.331
# Method:                 Least Squares   F-statistic:                 3.875e+04
# Date:                Fri, 18 Nov 2022   Prob (F-statistic):               0.00
# Time:                        13:25:23   Log-Likelihood:            -6.8993e+05
# No. Observations:              391063   AIC:                         1.380e+06
# Df Residuals:                  391057   BIC:                         1.380e+06
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept       115.4599      2.120     54.474      0.000     111.306     119.614
# ...

# %%
# OLS with years as dummy variables
lm2 = smf.ols(formula = 'Rating~ compound + App + Gender + C(year)', data = df).fit()
print (lm2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Rating   R-squared:                       0.345
# Model:                            OLS   Adj. R-squared:                  0.345
# Method:                 Least Squares   F-statistic:                 1.586e+04
# Date:                Fri, 18 Nov 2022   Prob (F-statistic):               0.00
# Time:                        13:25:34   Log-Likelihood:            -6.8581e+05
# No. Observations:              391063   AIC:                         1.372e+06
# Df Residuals:                  391049   BIC:                         1.372e+06
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           3.0881      0.018    168.777      0.000       3.052       3.124
# ...

# %%
# Add interaction
lm2 = smf.ols(formula = 'Rating~ compound + App + Gender + App*Gender', data = df).fit()
print (lm2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Rating   R-squared:                       0.327
# Model:                            OLS   Adj. R-squared:                  0.327
# Method:                 Least Squares   F-statistic:                 3.161e+04
# Date:                Fri, 18 Nov 2022   Prob (F-statistic):               0.00
# Time:                        13:25:34   Log-Likelihood:            -6.9131e+05
# No. Observations:              391063   AIC:                         1.383e+06
# Df Residuals:                  391056   BIC:                         1.383e+06
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       2.5909      0.006    459.784      0.000       2.580       2.602
# ...
